# %%
import sys, os, importlib
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

import src.portfolio_tracker.io as io
importlib.reload(io)                # reloads code from disk
from src.portfolio_tracker.io import load_holdings, fetch_prices

# %%
from pathlib import Path
from src.portfolio_tracker.io import load_holdings

csv_path = Path("../data/sample_holdings.csv").resolve()
print(csv_path)
holdings = load_holdings(str(csv_path))
holdings
# Out:
# /files/capstone_project_LB/data/sample_holdings.csv
#   account_id      asset_id asset_type   ticker currency  quantity  avg_cost
# 0       acc1  asset_equity     Equity     AAPL      USD     10.00       150
# 1       acc1     asset_etf        ETF      SPY      USD      5.00       400
# 2       acc1  asset_crypto     Crypto  BTC-USD      USD      0.02     35000

# %%
import matplotlib as plt
tickers = holdings["ticker"].astype(str)
print("Tickers:", tickers.tolist())
prices = fetch_prices(tickers, start="2023-01-01")
prices.head()


print("Prices shape:", prices.shape)
ax = prices.ffill().plot(figsize=(10,7))
ax.set_title("Adjusted Close Prices")
ax.set_xlabel("Date")
ax.set_ylabel("Price")
plt.show()
# Out:
# Tickers: ['AAPL', 'SPY', 'BTC-USD']
# Prices shape: (1056, 15)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 13>()
#      11 ax.set_xlabel("Date")
#      12 ax.set_ylabel("Price")
# ---> 13 plt.show()
#
# File /opt/conda/lib/python3.8/site-packages/matplotlib/_api/__init__.py:222, in caching_module_getattr.<locals>.__getattr__(name)
#     220 if name in props:
#     221     return props[name].__get__(instance)
# --> 222 raise AttributeError(
#     223     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
print("Prices shape:", prices.shape)

import matplotlib.pyplot as plt
ax = prices.ffill().plot(figsize=(9,4))
ax.set_title("Adjusted Close Prices")
ax.set_xlabel("Date")
ax.set_ylabel("Price")
plt.show()
# Out:
# Prices shape: (1056, 15)

# %%
import importlib, src.portfolio_tracker.transform as tf
importlib.reload(tf)
from src.portfolio_tracker.transform import daily_returns, portfolio_returns

# %%
rets = daily_returns(prices)
display(rets.head())
print("Returns shape:", rets.shape, "| median abs mean:", rets.mean().abs().median())
# Out:
#                 AAPL       SPY   BTC-USD
# date
# 2023-01-03 -0.002140  0.028405 -0.005262
# 2023-01-04  0.013397 -0.035164 -0.015736
# 2023-01-05  0.002601  0.035901 -0.024214
# 2023-01-06 -0.010161  0.026214  0.009294
# 2023-01-09  0.007762  0.012033  0.016600
# Returns shape: (750, 3) | median abs mean: 0.00015970595641152886

# %%
port_ret = portfolio_returns(holdings, prices)
equity = (1 + port_ret).cumprod()
display(equity.tail())

import matplotlib.pyplot as plt
equity.plot(figsize=(9,4))
plt.title("Portfolio Equity (growth of 1)")
plt.xlabel("Date"); plt.ylabel("Value")
plt.show()
# Out:
# date
# 2025-11-11    1.162824
# 2025-11-12    1.130067
# 2025-11-13    1.139114
# 2025-11-14    1.142986
# 2025-11-17    1.146203
# Freq: B, Name: portfolio, dtype: float64

# %%
import importlib, src.portfolio_tracker.kpis as kp
importlib.reload(kp)
from src.portfolio_tracker.kpis import kpi_table, drawdown

kpi_table(port_ret).style.format("{:.4f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_ee57c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee57c_level0_col0" class="col_heading level0 col0" >Cumulative Return</th>
#       <th id="T_ee57c_level0_col1" class="col_heading level0 col1" >Ann. Vol</th>
#       <th id="T_ee57c_level0_col2" class="col_heading level0 col2" >Sharpe</th>
#       <th id="T_ee57c_level0_col3" class="col_heading level0 col3" >Max Drawdown</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee57c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ee57c_row0_col0" class="data row0 col0" >0.1462</td>
#       <td id="T_ee57c_row0_col1" class="data row0 col1" >0.2326</td>
#       <td id="T_ee57c_row0_col2" class="data row0 col2" >-21.3556</td>
#       <td id="T_ee57c_row0_col3" class="data row0 col3" >-0.3965</td>
#     </tr>
#   </tbody>
# </table>

# %%
dd = drawdown((1+port_ret).cumprod())
dd.plot(figsize=(9,3))
plt.title("Drawdown")
plt.show()

# %%
print("Hello")
# Out:
# Hello

# %%
import importlib, src.portfolio_tracker.risk_models as rm
importlib.reload(rm)
from src.portfolio_tracker.risk_models import realized_vol, build_vol_dataset

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve()
sys.path.append(str(ROOT))   # make sure "src" is importable

# %%
from pathlib import Path
import sys

# Find project root by walking up until we see a "src" folder
ROOT = Path.cwd()
while ROOT != ROOT.parent and not (ROOT / "src").exists():
    ROOT = ROOT.parent

print("Project root detected as:", ROOT)

# Add root to Python path so "src" becomes importable
sys.path.insert(0, str(ROOT))
# Out:
# Project root detected as: /files/capstone_project_LB

# %%
import importlib
import src.portfolio_tracker.risk_models as rm
importlib.reload(rm)

from src.portfolio_tracker.risk_models import realized_vol, build_vol_dataset

# %%
X, y = build_vol_dataset(
    port_ret,
    vol_windows=(5, 10, 20),
    ret_windows=(1, 5, 10),
    horizon=5,
)

print("X shape:", X.shape)
print("y shape:", y.shape)
display(X.head())
display(y.head())
# Out:
# X shape: (727, 6)
# y shape: (727,)
#                rv_5d    rv_10d    rv_20d  ret_1d_sum  ret_5d_sum  ret_10d_sum
# date
# 2023-01-30  0.170491  0.231763  0.235606    0.001166    0.013455    -0.031932
# 2023-01-31  0.148281  0.232549  0.234427    0.003430    0.024908    -0.030716
# 2023-02-01  0.118743  0.172044  0.234193   -0.001504    0.032138     0.000460
# 2023-02-02  0.117439  0.161089  0.229726    0.002853    0.025422    -0.008742
# 2023-02-03  0.033527  0.134712  0.230115    0.004571    0.010515     0.013700
# date
# 2023-01-30    0.033527
# 2023-01-31    0.039658
# 2023-02-01    0.066742
# 2023-02-02    0.144438
# 2023-02-03    0.167865
# Freq: B, Name: rv_next_5d, dtype: float64

# %%
holy shit that works

# %%
# !curl -I https://finance.yahoo.com
# Out:
# HTTP/2 429
# date: Thu, 20 Nov 2025 09:12:36 GMT
# server: ATS
# x-content-type-options: nosniff
# referrer-policy: no-referrer-when-downgrade
# content-length: 23
# content-type: text/html

# %%
import yfinance as yf
df = yf.download("AAPL", start="2024-01-01", end="2024-02-01", progress=False)
df.head()
# Out:
# Failed to get ticker 'AAPL' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['AAPL']: Exception('%ticker%: No timezone found, symbol may be delisted')
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
pip install yfinance
# Out:
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
# Requirement already satisfied: yfinance in /opt/conda/lib/python3.8/site-packages (0.2.37)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/conda/lib/python3.8/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: pandas>=1.3.0 in /opt/conda/lib/python3.8/site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: lxml>=4.9.1 in /opt/conda/lib/python3.8/site-packages (from yfinance) (5.2.1)
# Requirement already satisfied: pytz>=2022.5 in /opt/conda/lib/python3.8/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: requests>=2.31 in /opt/conda/lib/python3.8/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: html5lib>=1.1 in /opt/conda/lib/python3.8/site-packages (from yfinance) (1.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.8/site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: peewee>=3.16.2 in /opt/conda/lib/python3.8/site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/conda/lib/python3.8/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: appdirs>=1.4.4 in /opt/conda/lib/python3.8/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/conda/lib/python3.8/site-packages (from yfinance) (2.4.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.8/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: six>=1.9 in /opt/conda/lib/python3.8/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.8/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.8/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.31->yfinance) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.8/site-packages (from requests>=2.31->yfinance) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=2.31->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.31->yfinance) (1.26.9)
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
# WARNING: Ignoring invalid distribution -ygments (/opt/conda/lib/python3.8/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
print(yf.Ticker("AAPL").history(period="1d"))
# Out:
# Failed to get ticker 'AAPL' reason: Expecting value: line 1 column 1 (char 0)
# AAPL: No price data found, symbol may be delisted (period=1d)
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
import sys
print(sys.executable)
# Out:
# /opt/conda/bin/python

# %%
conda install -n myenv yfinance

# %%
prompt_holdings_csv()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 prompt_holdings_csv()
#
# NameError: name 'prompt_holdings_csv' is not defined

# %%
import src.prompt_holdings_csv as ph
ph()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 import src.prompt_holdings_csv as ph
#       2 ph()
#
# ModuleNotFoundError: No module named 'src'

# %%
from pathlib import Path
from src.portfolio_tracker.io import prompt_holding_csv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 from pathlib import Path
# ----> 2 from src.portfolio_tracker.io import prompt_holding_csv
#
# ModuleNotFoundError: No module named 'src'
